# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_table(f'../data/DADOS/DADOS_INEP_ENEM.csv', low_memory=False, sep=',')

# %%
df
# Out:
#         Unnamed: 0  NU_ANO  CO_UF_ESCOLA SG_UF_ESCOLA  CO_MUNICIPIO_ESCOLA  \
# 0                0    2007            11           RO              1100205
# 1                1    2006            11           RO              1100205
# 2                2    2005            11           RO              1100205
# 3                3    2008            11           RO              1100205
# 4                4    2007            11           RO              1100205
# 5                5    2008            11           RO              1100205
# 6                6    2005            11           RO              1100205
# 7                7    2005            11           RO              1100205
# 8                8    2006            11           RO              1100205
# 9                9    2008            11           RO              1100205
# 10              10    2008            11           RO              1100205
# ...
